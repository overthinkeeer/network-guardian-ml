# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/friday.csv")

# %%
df.head()
# Out:
#    Src IP dec  Src Port  Dst IP dec  Dst Port  Protocol Timestamp  \
# 0  3232238130     56108  3232238083      3268         6   59:50.3
# 1  3232238130     42144  3232238083       389         6   59:50.3
# 2   134610945         0   134219268         0         0   00:31.4
# 3  3232238105      5353  3758096635      5353        17   00:42.9
# 4  3232238105       123   301796989       123        17   00:42.4
#
#    Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0      112740690                32                 16
# 1      112740560                32                 16
# 2      113757377               545                  0
# 3       91997219               388                  0
# 4       66966070                 6                  6
#
#    Total Length of Fwd Packet  ...  Active Min    Idle Mean      Idle Std  \
# 0                        6448  ...         343  16105402.14  4.988048e+05
# 1                        6448  ...         285  16105427.43  4.987937e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Src IP dec                  547557 non-null  int64
#  1   Src Port                    547557 non-null  int64
#  2   Dst IP dec                  547557 non-null  int64
#  3   Dst Port                    547557 non-null  int64
#  4   Protocol                    547557 non-null  int64
#  5   Timestamp                   547557 non-null  object
#  6   Flow Duration               547557 non-null  int64
#  7   Total Fwd Packet            547557 non-null  int64
#  8   Total Bwd packets           547557 non-null  int64
#  9   Total Length of Fwd Packet  547557 non-null  int64
#  10  Total Length of Bwd Packet  547557 non-null  int64
#  11  Fwd Packet Length Max       547557 non-null  int64
#  12  Fwd Packet Length Min       547557 non-null  int64
# ...

# %%
df['ICMP Type'].value_counts()
# Out:
# ICMP Type
# -1    547382
#  3       143
#  8        31
#  0         1
# Name: count, dtype: int64

# %%
df['ICMP Code'].value_counts()
# Out:
# ICMP Code
# -1     547382
#  1        114
#  0         32
#  3         25
#  10         4
# Name: count, dtype: int64

# %%
df[df["ICMP Type"] != -1]["Label"].value_counts()
# Out:
# Label
# BENIGN      151
# Portscan     24
# Name: count, dtype: int64

# %%
df[df["ICMP Code"] != -1]["Label"].value_counts()
# Out:
# Label
# BENIGN      151
# Portscan     24
# Name: count, dtype: int64

# %%
df.columns[df.nunique() <= 2].tolist()
# Out:
# ['Fwd URG Flags',
#  'Bwd URG Flags',
#  'URG Flag Count',
#  'Subflow Fwd Packets',
#  'Subflow Bwd Packets',
#  'Attempted Category']

# %%
df['Subflow Fwd Packets'].value_counts()
# Out:
# Subflow Fwd Packets
# 0    544327
# 1      3230
# Name: count, dtype: int64

# %%
df['Subflow Bwd Packets'].value_counts()
# Out:
# Subflow Bwd Packets
# 0    547556
# 1         1
# Name: count, dtype: int64

# %%
df['Attempted Category'].value_counts()
# Out:
# Attempted Category
# -1    543490
#  1      4067
# Name: count, dtype: int64

# %%
df['CWR Flag Count'].value_counts()
# Out:
# CWR Flag Count
# 0     547423
# 1        121
# 2          6
# 3          2
# 6          2
# 23         1
# 9          1
# 8          1
# Name: count, dtype: int64

# %%
df['URG Flag Count'].value_counts()
# Out:
# URG Flag Count
# 0    547557
# Name: count, dtype: int64

# %%
df['ECE Flag Count'].value_counts()
# Out:
# ECE Flag Count
# 0    547461
# 2        83
# 1        13
# Name: count, dtype: int64

# %%
len(df[(df['Subflow Fwd Packets'] == 0) & (df['Subflow Fwd Bytes'] > 0)])
# Out:
# 370357

# %%
df[['Total Fwd Packet', 'Subflow Fwd Packets']].head(10)
# Out:
#    Total Fwd Packet  Subflow Fwd Packets
# 0                32                    0
# 1                32                    0
# 2               545                    1
# 3               388                    1
# 4                 6                    0
# 5                 6                    0
# 6               124                    0
# 7                10                    0
# 8                 4                    0
# 9               206                    0

# %%
df[["Fwd Segment Size Avg", "Bwd Segment Size Avg", "Fwd Packet Length Mean", "Bwd Packet Length Mean"]].head(10)
# Out:
#    Fwd Segment Size Avg  Bwd Segment Size Avg  Fwd Packet Length Mean  \
# 0            201.500000             72.000000              201.500000
# 1            201.500000            316.000000              201.500000
# 2              0.000000              0.000000                0.000000
# 3             95.750000              0.000000               95.750000
# 4             48.000000             48.000000               48.000000
# 5             48.000000             48.000000               48.000000
# 6            275.725806            401.200000              275.725806
# 7            160.200000            589.666667              160.200000
# 8             48.000000             48.000000               48.000000
# 9            205.116505            289.252632              205.116505
#
#    Bwd Packet Length Mean
# 0               72.000000
# 1              316.000000
# 2                0.000000
# 3                0.000000
# 4               48.000000
# 5               48.000000
# ...

# %%
df[["Packet Length Variance", "Packet Length Std"]].head(10)
# Out:
#    Packet Length Variance  Packet Length Std
# 0            31450.099290         177.341758
# 1            30619.460990         174.984173
# 2                0.000000           0.000000
# 3             3112.001938          55.785320
# 4                0.000000           0.000000
# 5                0.000000           0.000000
# 6           251692.678900         501.689823
# 7           443664.134500         666.081177
# 8                0.000000           0.000000
# 9           175496.533900         418.923065

# %%
df = df.drop(["Src IP dec", "Src Port", "Dst IP dec", "Dst Port", "Timestamp", 
              "Attempted Category", "ICMP Code", "ICMP Type", "URG Flag Count", 
              "Fwd URG Flags", "Bwd URG Flags", "Subflow Bwd Packets",
              "Subflow Bwd Bytes", "CWR Flag Count", "ECE Flag Count", "Subflow Fwd Packets",
              "Subflow Fwd Bytes", "Fwd Segment Size Avg", "Bwd Segment Size Avg",
              "Packet Length Variance"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Protocol                    547557 non-null  int64
#  1   Flow Duration               547557 non-null  int64
#  2   Total Fwd Packet            547557 non-null  int64
#  3   Total Bwd packets           547557 non-null  int64
#  4   Total Length of Fwd Packet  547557 non-null  int64
#  5   Total Length of Bwd Packet  547557 non-null  int64
#  6   Fwd Packet Length Max       547557 non-null  int64
#  7   Fwd Packet Length Min       547557 non-null  int64
#  8   Fwd Packet Length Mean      547557 non-null  float64
#  9   Fwd Packet Length Std       547557 non-null  float64
#  10  Bwd Packet Length Max       547557 non-null  int64
#  11  Bwd Packet Length Min       547557 non-null  int64
#  12  Bwd Packet Length Mean      547557 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Protocol', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd RST Flags', 'Bwd RST Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
#        'Packet Length Std', 'FIN Flag Count', 'SYN Flag Count',
# ...

# %%
df[["Flow Duration", "Total TCP Flow Time"]].head(10)
# Out:
#    Flow Duration  Total TCP Flow Time
# 0      112740690            112740690
# 1      112740560            112740560
# 2      113757377                    0
# 3       91997219                    0
# 4       66966070                    0
# 5       66137889                    0
# 6      106176490            106176490
# 7       79593267             79593267
# 8       64318195                    0
# 9      116933759            116933759

# %%
counts = df.nunique()
counts[counts == 1]
# Out:
# Series([], dtype: int64)

# %%
df.to_csv("../data/friday_cleaned.csv", index=False)
